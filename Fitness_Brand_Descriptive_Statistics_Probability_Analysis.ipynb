# %% [markdown]
# **Problem Statements :**
# to identify the characteristics of the target audience for each type of treadmill.

# %%
# !gdown 18nZGqs13Eo29aNZOiVFk8ChohIhS9sCG
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=18nZGqs13Eo29aNZOiVFk8ChohIhS9sCG
# To: /content/aerofit_treadmill.csv
# 100% 7.28k/7.28k [00:00<00:00, 8.41MB/s]

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv('/content/aerofit_treadmill.csv')

# %%
data
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %% [markdown]
# After looking into data, we need to analyze how AeroFit treadmill product is related to differnt attributes available in the data set.

# %%
#shape of the dataset
data.shape
# Out:
# (180, 9)

# %%
#differnt attributes and there data types
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
#checking for missing values
data.isna().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %% [markdown]
# No missing value detected, so we have a clean dataset.

# %%
data.head(10)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47
# 5   KP281   20  Female         14     Partnered      3        3   32973     66
# 6   KP281   21  Female         14     Partnered      3        3   35247     75
# 7   KP281   21    Male         13        Single      3        3   32973     85
# 8   KP281   21    Male         15        Single      5        4   35247    141
# 9   KP281   21  Female         15     Partnered      2        3   37521     85

# %%
#number of unique products we have in the data set
data["Product"].nunique()
# Out:
# 3

# %%
#count of each product type
data["Product"].value_counts()
# Out:
# KP281    80
# KP481    60
# KP781    40
# Name: Product, dtype: int64

# %%
#highest sales among products
cost = pd.DataFrame({"Product": ['KP281', 'KP481', 'KP781'],'Cost':[1500,1750,2500], 'Quantity':[80,60,40]})
cost['value'] = cost["Cost"] * cost["Quantity"]
cost
# Out:
#   Product  Cost  Quantity   value
# 0   KP281  1500        80  120000
# 1   KP481  1750        60  105000
# 2   KP781  2500        40  100000

# %%
#highest value sales product
plt.bar(cost["Product"], cost["value"])
plt.title("Frequency of each product type")
plt.show()

# %% [markdown]
# KP281 gives highest sales value

# %%
#Pie chart to understand products distribution
data['Product'].value_counts().plot(kind='pie',autopct="%.2f")
plt.title("Products Distribution")
plt.show()

# %% [markdown]
# *    Marginal Probability of KP281, KP481, KP781 selling are 44.44%, 33.33% and 22.22% respectively.
# *  Insight : KP281 is the highest number of selling product in last 3 months

# %%
#gender division of all the customers
data["Gender"].value_counts()
# Out:
# Male      104
# Female     76
# Name: Gender, dtype: int64

# %%
#Pie chart to understand gender distribution
data['Gender'].value_counts().plot(kind='pie',autopct="%.2f")
plt.title("Gender Distribution across customers")
plt.show()

# %% [markdown]
# *   Marginal Probability of Male and Female customers are 57.78% and 42.22% respectively.
#
# *    Insights: In distribution Male customers are higher

# %%
#Marital Status distribution of all the customers
data["MaritalStatus"].value_counts()
# Out:
# Partnered    107
# Single        73
# Name: MaritalStatus, dtype: int64

# %%
#Pie chart to understand Marital Status distribution
data['MaritalStatus'].value_counts().plot(kind='pie',autopct="%.2f")
plt.title("Gender Distribution across customers")
plt.show()

# %% [markdown]
# *   Marginal Probability of Single and Partnered customers are 40.56% and 59.44% respectively.
# *    Insights: Partnered customers are higher in numbers

# %%
#to check mean values and distribution for differnt attributes 
data.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
data.describe(include='object').T
# Out:
#               count unique        top freq
# Product         180      3      KP281   80
# Gender          180      2       Male  104
# MaritalStatus   180      2  Partnered  107

# %%
#to check the median values and outlier detection for Age across customers
plt.figure(figsize=(8,6))
sns.boxplot(data=data,
y="Age")
plt.title("Age Distribution across customers")
plt.show()

# %% [markdown]
# Median age of customers is 26 years old and few outliers detected.

# %%
#to check the median values and outlier detection for Education in years across customers
plt.figure(figsize=(8,6))
sns.boxplot(data=data,
y="Education")
plt.title("Education Distribution across customers")
plt.show()

# %% [markdown]
# Median Education of customers is 14 years and few outliers detected.

# %%
#to check the median values and outlier detection for Education in years across customers
plt.figure(figsize=(8,6))
sns.boxplot(data=data,
y="Income")
plt.title("Income Distribution across customers")
plt.show()

# %% [markdown]
# Median Income of customers is 50000 and few outliers detected.

# %%
#Product wise Maritial Status Distribution
plt.figure(figsize=(8,6))
sns.countplot(x='Product', hue='MaritalStatus', data=data)
plt.ylabel("Frequency")
plt.title("Product wise Maritial Status Distribution")
plt.show()

# %% [markdown]
# From the above chart, we can see partnered customer portion is higher in all three product category.

# %%
#Product wise Gender Distribution
plt.figure(figsize=(8,6))
sns.countplot(x='Product', hue='Gender', data=data)
plt.ylabel("Frequency")
plt.title("Product wise Gender Distribution")
plt.show()

# %% [markdown]
# From the above chart, we  can infer for KP281 male and Female customer portion is same and for KP481 and KP781 male customer portion is higher.

# %%
# Contingency Table for Product and Gender
pd.crosstab(index=data["Product"], columns=data["Gender"], margins=True, )
# Out:
# Gender   Female  Male  All
# Product
# KP281        40    40   80
# KP481        29    31   60
# KP781         7    33   40
# All          76   104  180

# %%
#Conditional Probability of Products given gender P(Product | Gender)
pd.crosstab(data.Product, data.Gender, normalize='columns')
# Out:
# Gender     Female      Male
# Product
# KP281    0.526316  0.384615
# KP481    0.381579  0.298077
# KP781    0.092105  0.317308

# %% [markdown]
# We can infer from the above contingency table following things,
#
#
# *   Probability of buying KP281 given a female customer is 52.63%.
# *   Probability of buying KP281 given a male customer is 38.46%.

# %%
#Conditional Probability of Gender given Product P(Gender | Product)
pd.crosstab(data.Product, data.Gender, normalize='index')
# Out:
# Gender     Female      Male
# Product
# KP281    0.500000  0.500000
# KP481    0.483333  0.516667
# KP781    0.175000  0.825000

# %% [markdown]
# We can infer from the above contingency table following things,
#
#
# *   Probability of a female buying given that it is KP781 product is 17.5%.
# *   Probability of a male buying given that it is KP781 product is 82.5%.

# %%
# Contingency Table for Product and Marital Status
pd.crosstab(index=data["Product"], columns=data["MaritalStatus"], margins=True)
# Out:
# MaritalStatus  Partnered  Single  All
# Product
# KP281                 48      32   80
# KP481                 36      24   60
# KP781                 23      17   40
# All                  107      73  180

# %%
#Conditional Probability of Products given Marital Status P(Product | Marital Status)
pd.crosstab(data.Product, data.MaritalStatus, normalize='columns')
# Out:
# MaritalStatus  Partnered    Single
# Product
# KP281           0.448598  0.438356
# KP481           0.336449  0.328767
# KP781           0.214953  0.232877

# %% [markdown]
# We can infer from the above contingency table following things,
#
#
# *   Probability of buying KP281 given a Partnered customer is 44.85%.
# *   Probability of buying KP281 given a Single customer is 43.83%.

# %%
#Conditional Probability of Marital Status given Products P(Marital Status | Product)
pd.crosstab(data.Product, data.MaritalStatus, normalize='index')
# Out:
# MaritalStatus  Partnered  Single
# Product
# KP281              0.600   0.400
# KP481              0.600   0.400
# KP781              0.575   0.425

# %% [markdown]
# We can infer from the above contingency table following things,
#
#
# *   Probability of buying by an Partnered customer  given that KP281 is the product  is 60%.
# *   Probability of buying by an Partnered customer given that KP281  is the product  is 40%.

# %%
# Contingency Table for Product and Usage
pd.crosstab(index=data["Product"], columns=data["Usage"], margins=True)
# Out:
# Usage     2   3   4   5  6  7  All
# Product
# KP281    19  37  22   2  0  0   80
# KP481    14  31  12   3  0  0   60
# KP781     0   1  18  12  7  2   40
# All      33  69  52  17  7  2  180

# %%
#Conditional Probability of Products given Usage P(Product | Usage)
pd.crosstab(data.Product, data.Usage, normalize='columns')
# Out:
# Usage           2         3         4         5    6    7
# Product
# KP281    0.575758  0.536232  0.423077  0.117647  0.0  0.0
# KP481    0.424242  0.449275  0.230769  0.176471  0.0  0.0
# KP781    0.000000  0.014493  0.346154  0.705882  1.0  1.0

# %% [markdown]
# We can infer from the above contingency table following things,
#
# *   Probability of buying KP281 given Usage is 2 is 57.57%.
# *   Probability of buying KP281 given Usage is 5 is 11.7%.

# %%
#Conditional Probability of Usage given Products P(Usage | Product)
pd.crosstab(data.Product, data.Usage, normalize='index')
# Out:
# Usage           2         3      4      5      6     7
# Product
# KP281    0.237500  0.462500  0.275  0.025  0.000  0.00
# KP481    0.233333  0.516667  0.200  0.050  0.000  0.00
# KP781    0.000000  0.025000  0.450  0.300  0.175  0.05

# %% [markdown]
# We can infer from the above contingency table following things,
#
# *   Probability of Usage is 3 given that buying KP281 is 46.25%.
# *   Probability of Usage is 2 given that buying KP281 is 23.75%

# %%
# Contingency Table for Product and Fitness
pd.crosstab(index=data["Product"], columns=data["Fitness"], margins=True)
# Out:
# Fitness  1   2   3   4   5  All
# Product
# KP281    1  14  54   9   2   80
# KP481    1  12  39   8   0   60
# KP781    0   0   4   7  29   40
# All      2  26  97  24  31  180

# %%
#Conditional Probability of Products given Fitness P(Product | Fitness)
pd.crosstab(data.Product, data.Fitness, normalize='columns')
# Out:
# Fitness    1         2         3         4         5
# Product
# KP281    0.5  0.538462  0.556701  0.375000  0.064516
# KP481    0.5  0.461538  0.402062  0.333333  0.000000
# KP781    0.0  0.000000  0.041237  0.291667  0.935484

# %% [markdown]
# We can infer from the above contingency table following things,
#
# *   Probability of buying KP281 given Fitness rating is 5 is 6.45%.
# *   Probability of buying KP281 given Fitness rating is 3 55.67%.

# %%
#Conditional Probability of Fitness given Products P(Fitness | Product )
pd.crosstab(data.Product, data.Fitness, normalize='columns')
# Out:
# Fitness    1         2         3         4         5
# Product
# KP281    0.5  0.538462  0.556701  0.375000  0.064516
# KP481    0.5  0.461538  0.402062  0.333333  0.000000
# KP781    0.0  0.000000  0.041237  0.291667  0.935484

# %% [markdown]
# We can infer from the above contingency table following things,
#
# *   Probability of Fitness rating is 3 given that buying KP281 is 55.67%.
# *   Probability of Fitness rating is 2 given that buying KP281 is 53.84%

# %%
#checking range of values for Income
data.sort_values(by = ['Income'], ascending=True)

# %%
#conversion of Income to categorical attributes to analyze
dur_point=[1,20000,40000,60000,80000,100000,120000]
dur_labels=["under 20K","20K-40K","40K-60K","60K-80K","80K-100K","100K above"]
data["Income_Slab"]=pd.cut(data["Income"],
bins=dur_point,
labels=dur_labels) 
data
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles Income_Slab
# 0      112     20K-40K
# 1       75     20K-40K
# ...

# %%
#Product wise buyers income range
plt.figure(figsize=(8,6))
sns.countplot(x='Product', hue='Income_Slab', data=data)
plt.ylabel("Frequency of order")
plt.title("Product wise buyers income range distribution")
plt.show()

# %% [markdown]
# From the above chart we can infer that for KP281 & KP481, the highest portion of customer has income range is 40K-60 K and for KP781 it is 80K-100K

# %%
#checking range of values for Miles
data.sort_values(by = ['Miles'], ascending=True)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 117   KP481   31  Female         18        Single      2        1   65220
# 19    KP281   23  Female         15     Partnered      2        2   34110
# 51    KP281   29  Female         14     Partnered      2        2   46617
# 59    KP281   33  Female         16        Single      2        2   55713
# 106   KP481   25  Female         14        Single      2        2   45480
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 155   KP781   25    Male         18     Partnered      6        5   75946
# 170   KP781   31    Male         16     Partnered      6        5   89641
# 167   KP781   30  Female         16     Partnered      6        5   90886
# 166   KP781   29    Male         14     Partnered      7        5   85906
# 173   KP781   35    Male         16     Partnered      4        5   92131
#
#      Miles
# 117     21
# 19      38
# 51      38
# 59      38
# 106     42
# ...

# %%
#conversion of expected Miles to run per week to categorical attributes to analyze
dur_point=[1,50,100,150,200,250,300,360]
dur_labels=["1-50 Miles","51-100 Miles","101-150 Miles","151-200 Miles","201-250 Miles","251-300 Miles", "300-360 Miles"]
data["Miles_Slab"]=pd.cut(data["Miles"],
bins=dur_point,
labels=dur_labels) 
data
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles Income_Slab     Miles_Slab
# 0      112     20K-40K  101-150 Miles
# ...

# %%
#Product wise buyers expected Miles to run per week range
plt.figure(figsize=(8,6))
sns.countplot(x='Product', hue='Miles_Slab', data=data)
plt.ylabel("Frequency of order")
plt.title("Product wise buyers expected Miles to run per week range")
plt.show()

# %% [markdown]
# From the above chart we can infer that for KP281 & KP481, the highest portion of customer has expected Miles run per week is 51-100 Miles and for KP781 it is 151-200 Miles.

# %%
#For correlation of Product with other atributes Education, Usage, Fitness, Income and Mile
sns.pairplot(data=data,hue="Product")
plt.title("correlation of Product with other atributes Education, Usage, Fitness, Income and Mile")
plt.show()

# %% [markdown]
# From the above pair plot we can infer that,
#
#
# *   KP781 is preffered among 25 to 35 years age group.
# *   Customers with higher education going for KP281 product.
# *   Medium range usage (3-5) going for KP481 product.

# %% [markdown]
# # customer profile for each AeroFit treadmill product

# %% [markdown]
# #KP281:
#
#
# *   Partnered people more prefer this than Single.
# *   Male and Female equally likes this product.
# *   40K-60K income range customer buys this more than any other income group.
# *   51- 100 Miles weekly expected running category customer prefer this.
# * 3 times per week usage custmers prefer this 46.25% times which is highest in any other usage.
# * Fitness ratings of 3 custmers prefer this 55.67% times which is highest in any other Fitness ratings.

# %% [markdown]
# #KP481:
#
#
# *   Partnered customers buys this more than Single.
# *   Male customers more likes this product than Female.
# *   40K-60K income range customer buys this more than any other income group.
# *   51- 100 Miles weekly expected running category customer prefer this.
# *  3 times per week usage custmers prefer this 51.66% times which is highest in any other usage.
# *  Fitness ratings of 2 custmers prefer this 46.15% times which is highest in any other Fitness ratings.

# %% [markdown]
# #KP781:
#
#
# *   Partnered customers buys this more than Single.
# *   Male customers more likes this product than Female.
# *   80K-100K income range customer buys this more than any other income group.
# *   151- 200 Miles weekly expected running category customer prefer this.
# * 4 times per week usage custmers prefer this 45% times which is highest in any other usage.
# * Fitness ratings of 5 custmers prefer this 93.54% times which is highest in any other Fitness ratings.

# %% [markdown]
# ##Recommendations
#
#
# *   KP281 product should be mostly sold to customers with Fitness Rating 3, KP481 product should be mostly sold to customers with Fitness Rating 2 and KP781 product should be sold to customers with Fitness Rating 5.
# *   KP281 product should be manufactured more as this the highest selling and highest value generating product.
# *   Major customer income slab is 40K- 60K, they are buying more than any other income groups.
# *   Partnered customers are buying more than Single customers across 3 products, so they should be targeted.
# *   Customers with higher education years going for K281 product, so they should be targeted for this product.
# *   Customers who has a target of running 51 to 100 Miles per week should be targeted for KP281 and KP481 product and who has a target of 151 to 200 Miles should be targeted for KP781 product.
# *   Female Customers should be targeted for mostly KP281 and KP481.
# *   KP781 product should be targeted to customers below 35 years age.
